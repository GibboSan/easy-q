# %%
# create experiments bash script
# !python automate.py --template template.yaml --variations variations.yaml --python_exec python3 --script ../../run_performance.py --slurm_options slurm_options.yaml
# Out:
# Creato: exp_20260109_225424/N_nodes50_N_layers1/N_nodes50_N_layers1.yaml
# Creato: exp_20260109_225424/N_nodes55_N_layers1/N_nodes55_N_layers1.yaml
# Creato: exp_20260109_225424/N_nodes60_N_layers1/N_nodes60_N_layers1.yaml
# Creato: exp_20260109_225424/N_nodes65_N_layers1/N_nodes65_N_layers1.yaml
# Creato: exp_20260109_225424/N_nodes70_N_layers1/N_nodes70_N_layers1.yaml
# Creato: exp_20260109_225424/N_nodes75_N_layers1/N_nodes75_N_layers1.yaml
# Script bash generato: exp_20260109_225424/run_all.sh
# Script SLURM generato: exp_20260109_225424/run_all_slurm.sh
#
# Per eseguire:
#   cd exp_20260109_225424 && ./run_all.sh       # sequenziale
#                     ./run_all_slurm.sh  # parallelo via SLURM

# %%
# write the experiments name on `exp_<date_stamp>`, run all experiments and merge outputs
exp_datestamp = 'exp_20260109_225424'
# !cd {exp_datestamp} && ./run_all.sh && cd .. && python ../merge_output.py {exp_datestamp}
# Out:
# ✅ File CSV creato: exp_20260109_225424/merged_results.csv
# ✅ File Excel creato: exp_20260109_225424/merged_results.xlsx
