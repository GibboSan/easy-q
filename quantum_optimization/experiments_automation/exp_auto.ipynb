# %%
# create experiments bash script
# !cd quantum_optimization/experiments_automation
# !python automate.py --template template.yaml --variations variations.yaml --python_exec python3 --script ../../run_performance.py --slurm_options slurm_options.yaml
# Out:
# /bin/bash: line 1: cd: quantum_optimization/experiments_automation: No such file or directory
# Creato: exp_20260108_174717/T0.5/T0.5.yaml
# Creato: exp_20260108_174717/T0.1/T0.1.yaml
# Creato: exp_20260108_174717/T0.05/T0.05.yaml
# Creato: exp_20260108_174717/T0.01/T0.01.yaml
# Script bash generato: exp_20260108_174717/run_all.sh
# Script SLURM generato: exp_20260108_174717/run_all_slurm.sh
#
# Per eseguire:
#   cd exp_20260108_174717 && ./run_all.sh       # sequenziale
#                     ./run_all_slurm.sh  # parallelo via SLURM

# %%
# write the experiments name on `exp_<date_stamp>`, run all experiments and merge outputs
exp_datestamp = 'exp_20260108_174717 '
# !cd {exp_datestamp} && ./run_all.sh
# Out:
# Traceback (most recent call last):
#   File "/home/gibbo/Documents/PhD/Spindox/easy-q/quantum_optimization/experiments_automation/exp_20260108_174717/../../run_performance.py", line 66, in <module>
#     main()
#   File "/home/gibbo/Documents/PhD/Spindox/easy-q/quantum_optimization/experiments_automation/exp_20260108_174717/../../run_performance.py", line 58, in main
#     output_dict = estimator_performance_run(parameter_dict)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gibbo/Documents/PhD/Spindox/easy-q/quantum_optimization/pipeline/performance.py", line 119, in estimator_performance_run
#     ideal_backend = get_aer_from_backend(seed, backend, noise_model=NoiseModel())
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gibbo/Documents/PhD/Spindox/easy-q/quantum_optimization/pipeline/backends.py", line 20, in get_aer_from_backend
#     return AerSimulator.from_backend(backend, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gibbo/Documents/PhD/Spindox/easy-q/.venv/lib/python3.11/site-packages/qiskit_aer/backends/aer_simulator.py", line 852, in from_backend
#     coupling_map=list(backend.coupling_map.get_edges()),
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'get_edges'
# python: can't open file '/home/gibbo/Documents/PhD/Spindox/easy-q/quantum_optimization/experiments_automation/../merge_outputs.py': [Errno 2] No such file or directory

# %%
# !cd ../..
# !python merge_outputs.py experiments_automation/{exp_datestamp}
