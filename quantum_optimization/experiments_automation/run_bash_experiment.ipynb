# %%
# create experiments bash script
# !python automate.py --template template.yaml --variations variations.yaml --python_exec python3 --script ../../run_performance.py --slurm_options slurm_options.yaml
# Out:
# Creato: exp_20260227_181014/Groups3_Instruments3_Layers3/Groups3_Instruments3_Layers3.yaml
# Creato: exp_20260227_181014/Groups3_Instruments3_Layers5/Groups3_Instruments3_Layers5.yaml
# Creato: exp_20260227_181014/Groups3_Instruments5_Layers3/Groups3_Instruments5_Layers3.yaml
# Creato: exp_20260227_181014/Groups3_Instruments5_Layers5/Groups3_Instruments5_Layers5.yaml
# Creato: exp_20260227_181014/Groups3_Instruments7_Layers3/Groups3_Instruments7_Layers3.yaml
# Creato: exp_20260227_181014/Groups3_Instruments7_Layers5/Groups3_Instruments7_Layers5.yaml
# Creato: exp_20260227_181014/Groups3_Instruments9_Layers3/Groups3_Instruments9_Layers3.yaml
# Creato: exp_20260227_181014/Groups3_Instruments9_Layers5/Groups3_Instruments9_Layers5.yaml
# Creato: exp_20260227_181014/Groups5_Instruments3_Layers3/Groups5_Instruments3_Layers3.yaml
# Creato: exp_20260227_181014/Groups5_Instruments3_Layers5/Groups5_Instruments3_Layers5.yaml
# ...

# %%
# write the experiments name on `exp_<date_stamp>`, run all experiments and merge outputs
exp_datestamp = 'exp_20260227_181014'
# !cd {exp_datestamp} && ./run_all.sh && cd .. && python ../merge_output.py {exp_datestamp}
# Out:
# ^C

# %%
# Merge outputs of 'exp_<date_stamp>'
exp_datestamp = 'exp_20260330_142732'
# !python ../merge_output.py {exp_datestamp}
# Out:
# ✅ File CSV creato: exp_20260330_142732/merged_results.csv
# ✅ File Excel creato: exp_20260330_142732/merged_results.xlsx
